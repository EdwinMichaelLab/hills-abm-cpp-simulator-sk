# %%
import geopandas as gpd
import pandas as pd

gdf =gpd.read_file("C:/Users/sookim/Documents/shapefiles/2021_10_parcels_4_public/2021_10_parcels_4_public.shp")

# %%
gdf['Center_point'] = gdf['geometry'].centroid
gdf["x"] = gdf.Center_point.map(lambda p: p.x)
gdf["y"] = gdf.Center_point.map(lambda p: p.y)

# %%
gdf.crs
# Out:
# <Derived Projected CRS: PROJCS["NAD83 / Florida West (ftUS)",GEOGCS["NAD83 ...>
# Name: NAD83 / Florida West (ftUS)
# Axis Info [cartesian]:
# - [east]: Easting (US survey foot)
# - [north]: Northing (US survey foot)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf = gdf.to_crs("EPSG:4326")

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf["x"] = gdf.centroid.x
gdf["y"] = gdf.centroid.y
# Out:
# C:\Users\sookim\AppData\Local\Temp\ipykernel_28764\779457735.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["x"] = gdf.centroid.x
# C:\Users\sookim\AppData\Local\Temp\ipykernel_28764\779457735.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["y"] = gdf.centroid.y

# %%
df=pd.DataFrame(gdf)
df['zipcode_str']=df['SITE_ZIP'].astype(str)

# %%
df.iloc[0,:]
# Out:
# FOLIO                                                        None
# TYPE                                                        dummy
# PIN                                                          None
# DOR_C                                                        None
# OWNER                                                        None
# ADDR_1                                                       None
# ADDR_2                                                       None
# CITY                                                         None
# STATE                                                        None
# ZIP                                                          None
# COUNTRY                                                      None
# SUB                                                          None
# SITE_ADDR                                                    None
# SITE_CITY                                                    None
# SITE_ZIP                                                     None
# LEGAL1                                                       None
# LEGAL2                                                       None
# LEGAL3                                                       None
# LEGAL4                                                       None
# DBA                                                          None
# STRAP                                                        None
# tBEDS                                                         0.0
# tBATHS                                                        0.0
# tSTORIES                                                      0.0
# tUNITS                                                        0.0
# tBLDGS                                                        0.0
# TAXDIST                                                      None
# JUST                                                          0.0
# LAND                                                          0.0
# BLDG                                                          0.0
# EXF                                                           0.0
# ACT                                                             0
# EFF                                                             0
# HEAT_AR                                                       0.0
# ASD_VAL                                                       0.0
# TAX_VAL                                                       0.0
# MUNI                                                         None
# SD1                                                          None
# SD2                                                          None
# TIF                                                          None
# BASE                                                            0
# S_DATE                                                       None
# VI                                                           None
# S_AMT                                                         0.0
# ACREAGE                                                  0.000092
# NBHC                                                          0.0
# Edit_dt                                                2019-04-08
# geometry        POLYGON ((-82.72341633517281 27.63819486808930...
# x                                                      -82.723413
# y                                                       27.638192
# Center_point        POINT (421948.73889360577 1201855.4153981842)
# zipcode_str                                                  None
# Name: 0, dtype: object

# %%
ZIPS = ['33510', '33511', '33527', '33534', '33547', '33548', '33549', '33556', '33558', '33559', '33563', '33565',
        '33566', '33567', '33569', '33570', '33572', '33573', '33578', '33579', '33584', '33592', '33594', '33596',
        '33598', '33602', '33603', '33604', '33605', '33606', '33607', '33609', '33610', '33611', '33612', '33613',
        '33614', '33615', '33616', '33617', '33618', '33619', '33624', '33625', '33626', '33629', '33634', '33635',
        '33637', '33647',
        '33620', '33503']

# %%
df=df[df['zipcode_str']=='33647']
df
# Out:
#              FOLIO  TYPE                            PIN DOR_C  \
# 108883  0329006000  None  U-01-27-19-ZZZ-000001-12010.0  8300
# 108884  0329006102  None  A-01-27-19-88J-000001-00001.0  0106
# 108885  0329006104  None  A-01-27-19-88J-000001-00002.0  0106
# 108886  0329006106  None  A-01-27-19-88J-000001-00003.0  0106
# 108887  0329006108  None  A-01-27-19-88J-000001-00004.0  0106
# ...            ...   ...                            ...   ...
# 226008  0659131334  None  U-09-27-20-5HN-000000-E0000.0  0901
# 226009  0659131336  None  U-09-27-20-5HN-000000-F0000.0  0901
# 507036  2900000120  None  U-07-27-20-ZZZ-000001-88640.1  0029
# 507141  2900000225  None  U-03-27-19-ZZZ-000001-12110.1  0029
# 507274  2900000359  None  U-08-27-20-ZZZ-000001-89000.1  0029
#
#                                                    OWNER  \
# 108883               SCHOOL BOARD OF HILLSBOROUGH COUNTY
# 108884                  ERICA AUGUSTIN AND ZACHRY HARRIS
# 108885                                   JESSICA ORDONEZ
# 108886                                 Z & Z CAPITAL LLC
# 108887                                 LINDA E DETERDING
# ...                                                  ...
# 226008   MAGNOLIA TRACE AT CROSS CREEK PARCEL M ASSN INC
# 226009  MAGNOLIA TRACE AT CROSS CREEK PARCEL M ASSOC INC
# 507036                                      PUBLIC LANDS
# 507141                                      PUBLIC LANDS
# 507274                                      PUBLIC LANDS
#
#                             ADDR_1              ADDR_2       CITY STATE  \
# 108883                PROPERTY TAX  901 E KENNEDY BLVD      TAMPA    FL
# 108884  6419 REFLECTION DR APT 104                None  SAN DIEGO    CA
# 108885         20404 NEEDLETREE DR                None      TAMPA    FL
# 108886       18025 COZUMEL ISLE DR                None      TAMPA    FL
# 108887         20408 NEEDLETREE DR                None      TAMPA    FL
# ...                            ...                 ...        ...   ...
# 226008               PO BOX 342069                None      TAMPA    FL
# 226009               PO BOX 342069                None      TAMPA    FL
# 507036                     UNKNOWN                None       None  None
# 507141                     UNKNOWN                None       None  None
# 507274                     UNKNOWN                None       None  None
#
#                ZIP  ...    VI      S_AMT    ACREAGE      NBHC     Edit_dt  \
# 108883  33602-3597  ...     V  2085000.0  73.979301  216011.0  2020-03-23
# 108884  92124-3128  ...     I   197500.0   0.069676  216011.0  2019-03-01
# 108885  33647-3487  ...     I   151000.0   0.038062  216011.0  2019-03-01
# 108886  33647-3374  ...     I   208400.0   0.038021  216011.0  2019-03-01
# 108887  33647-3487  ...     I   173000.0   0.038021  216011.0  2019-03-01
# ...            ...  ...   ...        ...        ...       ...         ...
# 226008  33694-2069  ...  None        0.0   3.629180  216007.0  2019-03-09
# 226009  33694-2069  ...  None        0.0   0.770966  216007.0  2019-03-09
# 507036        None  ...  None        0.0   2.647960  216008.0  2019-03-09
# 507141        None  ...  None        0.0   5.024139  216011.0  2019-03-01
# 507274        None  ...  None        0.0   0.157789  216007.0  2019-07-25
#
#                                                  geometry          x  \
# 108883  POLYGON ((-82.35383 28.16098, -82.35381 28.160... -82.356572
# 108884  POLYGON ((-82.36765 28.16479, -82.36766 28.164... -82.367788
# 108885  POLYGON ((-82.36766 28.16487, -82.36794 28.164... -82.367803
# 108886  POLYGON ((-82.36767 28.16492, -82.36795 28.164... -82.367812
# 108887  POLYGON ((-82.36768 28.16497, -82.36796 28.164... -82.367822
# ...                                                   ...        ...
# 226008  POLYGON ((-82.31498 28.14768, -82.31490 28.147... -82.315236
# 226009  POLYGON ((-82.31362 28.14857, -82.31368 28.148... -82.313935
# 507036  POLYGON ((-82.33679 28.14736, -82.33686 28.147... -82.337432
# 507141  MULTIPOLYGON (((-82.39680 28.15927, -82.39690 ... -82.393516
# 507274  POLYGON ((-82.32522 28.15672, -82.32522 28.156... -82.325642
#
#                 y                    Center_point zipcode_str
# 108883  28.159383  POINT (541273.097 1390818.760)       33647
# 108884  28.164802  POINT (537665.014 1392799.772)       33647
# 108885  28.164871  POINT (537660.205 1392824.963)       33647
# 108886  28.164920  POINT (537657.437 1392842.758)       33647
# 108887  28.164968  POINT (537654.126 1392860.451)       33647
# ...           ...                             ...         ...
# 226008  28.147106  POINT (554580.476 1386318.438)       33647
# 226009  28.149469  POINT (555002.006 1387176.458)       33647
# 507036  28.147202  POINT (547427.993 1386372.836)       33647
# 507141  28.162689  POINT (529372.891 1392057.512)       33647
# 507274  28.156688  POINT (551236.494 1389811.035)       33647
#
# [21351 rows x 52 columns]

# %%
columns=['FOLIO', 'TYPE', 'PIN', 'DOR_C','SITE_ADDR', 'SITE_CITY', 'SITE_ZIP', 'tBEDS', 'tBATHS', 'tSTORIES', 'tUNITS', 'tBLDGS', 'ACREAGE', 'x', 'y', 'zipcode_str']
df=df[columns]

# %%
df.to_csv('../temp/presampled-points/33647.csv', index=False)
